# %% [markdown]
# ## 라이브러리 불러오기

# %%
import sys
import pandas as pd
import numpy as np

from catboost import CatBoostRegressor
import lightgbm as lgb
from sklearn.ensemble import GradientBoostingRegressor

from pycaret.regression import * 
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, mean_squared_error

from scipy import stats
from scipy.stats import norm, skew

from statsmodels.formula.api import ols

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Experiment 1
# - 실험 내용 : 원본 데이터로 학습시키기

# %%
train = pd.read_csv('C:/Users/cdbre/Desktop/MyLife/DACON/data/teacher_train.csv')

# %%
train = train[['ANONYMOUS_1','YEAR','FE','ANONYMOUS_2','ZN','V40','PQINDEX','NI','CU','MO','CR','Y_LABEL','Score_0']]

# %%
train.head()
# Out:
#    ANONYMOUS_1  YEAR   FE  ANONYMOUS_2   ZN    V40  PQINDEX  NI  CU  MO  CR  \
# 0         1486  2011  888          200   75  154.0     8504   6  78   1  13
# 1         1350  2021    2          375  652   44.0       19   0  31   0   0
# 2         2415  2015    4          200  412   72.6       17   0   2   0   1
# 3         7389  2010   37          200    7  133.3       44   0   1   0   0
# 4         3954  2015   71          200  128  133.1      217   0   0   0   0
#
#    Y_LABEL  Score_0
# 0        0   0.9949
# 1        0   0.9958
# 2        1   0.0017
# 3        0   0.7446
# 4        0   0.9915

# %%
train.describe()[['Score_0']]
# Out:
#             Score_0
# count  14095.000000
# mean       0.914513
# std        0.220244
# min        0.000500
# 25%        0.964300
# 50%        0.986800
# 75%        0.994100
# max        0.999600

# %%
# train, test로 분리
train, test = train_test_split(train, test_size=0.2, stratify=train.Y_LABEL, random_state=42)

# %%
print(train.shape)
print(test.shape)
# Out:
# (11276, 13)
# (2819, 13)

# %%
real_test = pd.read_csv('C:/Users/cdbre/Desktop/MyLife/DACON/data/test.csv')

# %%
real_test = real_test[['ANONYMOUS_1','YEAR','FE','ANONYMOUS_2','ZN','V40','PQINDEX','NI','CU','MO','CR']]

# %% [markdown]
# ## Metric
# - MSE 활용

# %% [markdown]
# ## AutoML

# %%
clf = setup(data = train,  
            target = 'Score_0',  # 타겟 데이터 설정
            ignore_features = ['Y_LABEL'],
            ordinal_features = {'YEAR' : ['2007','2008','2009','2010','2011','2012','2013','2014',
                                          '2015','2016','2017','2018','2019','2020','2021','2022']},  # YEAR 칼럼은 순서형
            numeric_features = ['ANONYMOUS_1', 'FE','ANONYMOUS_2', 'ZN', 'V40', 'PQINDEX', 'NI', 'CU', 'MO', 'CR'], 
            use_gpu = True,
            normalize=True, normalize_method = 'robust',  # 수치형 변수는 이상치가 많아 Robust Scaling 적용
            session_id = 42)
# Out:
# <style  type="text/css" >
#     #T_46ed0f29_7097_11ed_ad40_e0d4e81a3262row6_col1 {
#             background-color:  lightgreen;
#         }    #T_46ed0f29_7097_11ed_ad40_e0d4e81a3262row16_col1 {
#             background-color:  lightgreen;
#         }    #T_46ed0f29_7097_11ed_ad40_e0d4e81a3262row27_col1 {
#             background-color:  lightgreen;
#         }    #T_46ed0f29_7097_11ed_ad40_e0d4e81a3262row42_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_46ed0f29_7097_11ed_ad40_e0d4e81a3262" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row6_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row6_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row6_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row6_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row6_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_87028a6d_7097_11ed_88aa_e0d4e81a3262row6_col5 {
#             text-align:  left;
#             text-align:

# %%
gbr = create_model('gbr', cross_validation = False)
cat = create_model('catboost', cross_validation = False)
lgbm = create_model('lightgbm', cross_validation = False)
# Out:
#       MAE     MSE    RMSE     R2   RMSLE     MAPE
# 0  0.1138  0.0504  0.2245  0.064  0.1517  29.1192

# %%
print(gbr, '\n')
print(cat.get_all_params(), '\n')
print(lgbm)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
#
# {'nan_mode': 'Min', 'eval_metric': 'RMSE', 'iterations': 1000, 'sampling_frequency': 'PerTree', 'leaf_estimation_method': 'Newton', 'grow_policy': 'SymmetricTree', 'penalties_coefficient': 1, 'boosting_type': 'Plain', 'model_shrink_mode': 'Constant', 'feature_border_type': 'GreedyLogSum', 'bayesian_matrix_reg': 0.10000000149011612, 'eval_fraction': 0, 'force_unit_auto_pair_weights': False, 'l2_leaf_reg': 3, 'random_strength': 1, 'rsm': 1, 'boost_from_average': True, 'model_size_reg': 0.5, 'pool_metainfo_options': {'tags': {}}, 'subsample': 0.800000011920929, 'use_best_model': False, 'random_seed': 42, 'depth': 6, 'posterior_sampling': False, 'border_count': 254, 'classes_count': 0, 'auto_class_weights': 'None', 'sparse_features_conflict_fraction': 0, 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'model_shrink_rate': 0, 'min_data_in_leaf': 1, 'loss_function': 'RMSE', 'learning_rate': 0.05674700066447258, 'score_function': 'Cosine', 'task_type': 'CPU', 'leaf_estimation_iterations': 1, 'bootstrap_type': 'MVS', 'max_leaves': 64}
#
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               device='gpu', importance_type='split', learning_rate=0.1,
#               max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#               min_split_gain=0.0, n_estimators=100, n_jobs=-1, num_leaves=31,
#               objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#               silent='warn', subsample=1.0, subsample_for_bin=200000,
#               subsample_freq=0)

# %%
# GBR 파라미터 튜닝
tuned_gbr = tune_model(gbr, optimize='MSE', n_iter=10, search_library='optuna', choose_better=True)
# Out:
# <style  type="text/css" >
#     #T_3aac472c_7098_11ed_baf7_e0d4e81a3262row10_col0 {
#             background:  yellow;
#         }    #T_3aac472c_7098_11ed_baf7_e0d4e81a3262row10_col1 {
#             background:  yellow;
#         }    #T_3aac472c_7098_11ed_baf7_e0d4e81a3262row10_col2 {
#             background:  yellow;
#         }    #T_3aac472c_7098_11ed_baf7_e0d4e81a3262row10_col3 {
#             background:  yellow;
#         }    #T_3aac472c_7098_11ed_baf7_e0d4e81a3262row10_col4 {
#             background:  yellow;
#         }    #T_3aac472c_7098_11ed_baf7_e0d4e81a3262row10_col5 {
#             background:  yellow;
#         }</style><table id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row0_col0" class="data row0 col0" >0.1148</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row0_col1" class="data row0 col1" >0.0484</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row0_col2" class="data row0 col2" >0.2201</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row0_col3" class="data row0 col3" >0.0709</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row0_col4" class="data row0 col4" >0.1499</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row0_col5" class="data row0 col5" >30.2011</td>
#             </tr>
#             <tr>
#                         <th id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row1_col0" class="data row1 col0" >0.1069</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row1_col1" class="data row1 col1" >0.0402</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row1_col2" class="data row1 col2" >0.2005</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row1_col3" class="data row1 col3" >0.0799</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row1_col4" class="data row1 col4" >0.1357</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row1_col5" class="data row1 col5" >22.6723</td>
#             </tr>
#             <tr>
#                         <th id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row2_col0" class="data row2 col0" >0.1140</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row2_col1" class="data row2 col1" >0.0459</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row2_col2" class="data row2 col2" >0.2142</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row2_col3" class="data row2 col3" >0.0465</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row2_col4" class="data row2 col4" >0.1445</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row2_col5" class="data row2 col5" >22.4264</td>
#             </tr>
#             <tr>
#                         <th id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T
0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row7_col0" class="data row7 col0" >0.1157</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row7_col1" class="data row7 col1" >0.0496</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row7_col2" class="data row7 col2" >0.2228</td>
#                         <td id="T_3aac472c_7098_11ed_baf7_e0d4e81a3262row7_col3" class="data row7 col3" >0.0873</td>
#                         <td id

# %%
print(gbr, '\n')
print(tuned_gbr)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
#
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# Cat 파라미터 튜닝
tuned_cat = tune_model(cat, optimize='MSE', n_iter=10, search_library='optuna', choose_better=True)
# Out:
# <style  type="text/css" >
#     #T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row10_col0 {
#             background:  yellow;
#         }    #T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row10_col1 {
#             background:  yellow;
#         }    #T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row10_col2 {
#             background:  yellow;
#         }    #T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row10_col3 {
#             background:  yellow;
#         }    #T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row10_col4 {
#             background:  yellow;
#         }    #T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row10_col5 {
#             background:  yellow;
#         }</style><table id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row0_col0" class="data row0 col0" >0.1121</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row0_col1" class="data row0 col1" >0.0481</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row0_col2" class="data row0 col2" >0.2193</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row0_col3" class="data row0 col3" >0.0779</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row0_col4" class="data row0 col4" >0.1482</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row0_col5" class="data row0 col5" >29.3897</td>
#             </tr>
#             <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row1_col0" class="data row1 col0" >0.1025</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row1_col1" class="data row1 col1" >0.0389</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row1_col2" class="data row1 col2" >0.1973</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row1_col3" class="data row1 col3" >0.1092</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row1_col4" class="data row1 col4" >0.1333</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row1_col5" class="data row1 col5" >21.9510</td>
#             </tr>
#             <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row2_col0" class="data row2 col0" >0.1137</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row2_col1" class="data row2 col1" >0.0468</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row2_col2" class="data row2 col2" >0.2163</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row2_col3" class="data row2 col3" >0.0283</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row2_col4" class="data row2 col4" >0.1449</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row2_col5" class="data row2 col5" >22.0325</td>
#             </tr>
#             <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row3_col0" class="data row3 col0" >0.1060</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row3_col1" class="data row3 col1" >0.0445</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row3_col2" class="data row3 col2" >0.2109</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row3_col3" class="data row3 col3" >0.1044</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row3_col4" class="data row3 col4" >0.1418</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row3_col5" class="data row3 col5" >20.3612</td>
#             </tr>
#             <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row4_col0" class="data row4 col0" >0.1080</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row4_col1" class="data row4 col1" >0.0473</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row4_col2" class="data row4 col2" >0.2175</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row4_col3" class="data row4 col3" >0.0936</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row4_col4" class="data row4 col4" >0.1493</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row4_col5" class="data row4 col5" >28.6591</td>
#             </tr>
#             <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row5_col0" class="data row5 col0" >0.0980</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row5_col1" class="data row5 col1" >0.0362</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row5_col2" class="data row5 col2" >0.1903</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row5_col3" class="data row5 col3" >0.0386</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row5_col4" class="data row5 col4" >0.1281</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row5_col5" class="data row5 col5" >22.1305</td>
#             </tr>
#             <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row6_col0" class="data row6 col0" >0.1111</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row6_col1" class="data row6 col1" >0.0470</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row6_col2" class="data row6 col2" >0.2169</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row6_col3" class="data row6 col3" >0.0233</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row6_col4" class="data row6 col4" >0.1465</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row6_col5" class="data row6 col5" >31.7139</td>
#             </tr>
#             <tr>
#                         <th id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row7_col0" class="data row7 col0" >0.1093</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row7_col1" class="data row7 col1" >0.0469</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row7_col2" class="data row7 col2" >0.2166</td>
#                         <td id="T_aaf3ef4f_7098_11ed_94c1_e0d4e81a3262row7_col3" class="data row7 col3" >0.1372</td>
#                         <td id

# %%
print(cat.get_all_params(), '\n')
print(tuned_cat.get_all_params())
# Out:
# {'nan_mode': 'Min', 'eval_metric': 'RMSE', 'iterations': 1000, 'sampling_frequency': 'PerTree', 'leaf_estimation_method': 'Newton', 'grow_policy': 'SymmetricTree', 'penalties_coefficient': 1, 'boosting_type': 'Plain', 'model_shrink_mode': 'Constant', 'feature_border_type': 'GreedyLogSum', 'bayesian_matrix_reg': 0.10000000149011612, 'eval_fraction': 0, 'force_unit_auto_pair_weights': False, 'l2_leaf_reg': 3, 'random_strength': 1, 'rsm': 1, 'boost_from_average': True, 'model_size_reg': 0.5, 'pool_metainfo_options': {'tags': {}}, 'subsample': 0.800000011920929, 'use_best_model': False, 'random_seed': 42, 'depth': 6, 'posterior_sampling': False, 'border_count': 254, 'classes_count': 0, 'auto_class_weights': 'None', 'sparse_features_conflict_fraction': 0, 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'model_shrink_rate': 0, 'min_data_in_leaf': 1, 'loss_function': 'RMSE', 'learning_rate': 0.05674700066447258, 'score_function': 'Cosine', 'task_type': 'CPU', 'leaf_estimation_iterations': 1, 'bootstrap_type': 'MVS', 'max_leaves': 64}
#
# {'nan_mode': 'Min', 'eval_metric': 'RMSE', 'iterations': 102, 'sampling_frequency': 'PerTree', 'leaf_estimation_method': 'Newton', 'grow_policy': 'SymmetricTree', 'penalties_coefficient': 1, 'boosting_type': 'Plain', 'model_shrink_mode': 'Constant', 'feature_border_type': 'GreedyLogSum', 'bayesian_matrix_reg': 0.10000000149011612, 'eval_fraction': 0, 'force_unit_auto_pair_weights': False, 'l2_leaf_reg': 4, 'random_strength': 0.7446107864379883, 'rsm': 1, 'boost_from_average': True, 'model_size_reg': 0.5, 'pool_metainfo_options': {'tags': {}}, 'subsample': 0.800000011920929, 'use_best_model': False, 'random_seed': 42, 'depth': 8, 'posterior_sampling': False, 'border_count': 254, 'classes_count': 0, 'auto_class_weights': 'None', 'sparse_features_conflict_fraction': 0, 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'model_shrink_rate': 0, 'min_data_in_leaf': 1, 'loss_function': 'RMSE', 'learning_rate': 0.1271568387746811, 'score_function': 'Cosine', 'task_type': 'CPU', 'leaf_estimation_iterations': 1, 'bootstrap_type': 'MVS', 'max_leaves': 256}

# %%
# LGBM 파라미터 튜닝
tuned_lgbm = tune_model(lgbm, optimize='MSE', n_iter=10, search_library='optuna', choose_better=True)
# Out:
# <style  type="text/css" >
#     #T_dc54a39f_7098_11ed_b082_e0d4e81a3262row10_col0 {
#             background:  yellow;
#         }    #T_dc54a39f_7098_11ed_b082_e0d4e81a3262row10_col1 {
#             background:  yellow;
#         }    #T_dc54a39f_7098_11ed_b082_e0d4e81a3262row10_col2 {
#             background:  yellow;
#         }    #T_dc54a39f_7098_11ed_b082_e0d4e81a3262row10_col3 {
#             background:  yellow;
#         }    #T_dc54a39f_7098_11ed_b082_e0d4e81a3262row10_col4 {
#             background:  yellow;
#         }    #T_dc54a39f_7098_11ed_b082_e0d4e81a3262row10_col5 {
#             background:  yellow;
#         }</style><table id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row0_col0" class="data row0 col0" >0.1157</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row0_col1" class="data row0 col1" >0.0501</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row0_col2" class="data row0 col2" >0.2237</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row0_col3" class="data row0 col3" >0.0401</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row0_col4" class="data row0 col4" >0.1517</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row0_col5" class="data row0 col5" >30.1733</td>
#             </tr>
#             <tr>
#                         <th id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T
0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row5_col0" class="data row5 col0" >0.1006</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row5_col1" class="data row5 col1" >0.0361</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row5_col2" class="data row5 col2" >0.1900</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row5_col3" class="data row5 col3" >0.0414</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row5_col4" class="data row5 col4" >0.1279</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row5_col5" class="data row5 col5" >22.0567</td>
#             </tr>
#             <tr>
#                         <th id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row6_col0" class="data row6 col0" >0.1119</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row6_col1" class="data row6 col1" >0.0468</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row6_col2" class="data row6 col2" >0.2162</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row6_col3" class="data row6 col3" >0.0289</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row6_col4" class="data row6 col4" >0.1462</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row6_col5" class="data row6 col5" >31.7328</td>
#             </tr>
#             <tr>
#                         <th id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row7_col0" class="data row7 col0" >0.1159</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row7_col1" class="data row7 col1" >0.0495</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row7_col2" class="data row7 col2" >0.2225</td>
#                         <td id="T_dc54a39f_7098_11ed_b082_e0d4e81a3262row7_col3" class="data row7 col3" >0.0894</td>
#                         <td id

# %%
print(lgbm, '\n')
print(tuned_lgbm)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               device='gpu', importance_type='split', learning_rate=0.1,
#               max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#               min_split_gain=0.0, n_estimators=100, n_jobs=-1, num_leaves=31,
#               objective=None, random_state=42, reg_alpha=0.0, reg_lambda=0.0,
#               silent='warn', subsample=1.0, subsample_for_bin=200000,
#               subsample_freq=0)
#
# LGBMRegressor(bagging_fraction=0.7148538589793427, bagging_freq=3,
#               boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               device='gpu', feature_fraction=0.5825453457757226,
#               importance_type='split', learning_rate=0.3368892510399297,
#               max_depth=-1, min_child_samples=30, min_child_weight=0.001,
#               min_split_gain=0.21233911067827616, n_estimators=252, n_jobs=-1,
#               num_leaves=7, objective=None, random_state=42,
#               reg_alpha=1.0001718780584612e-08,
#               reg_lambda=1.040997312682199e-08, silent='warn', subsample=1.0,
#               subsample_for_bin=200000, subsample_freq=0)

# %%
real_train = train.copy()

# %%
train.drop(['Y_LABEL'], axis=1, inplace=True)

# %%
train_X = train.drop(['Score_0'], axis=1)
train_y = train['Score_0']

# %%
# YEAR
le = LabelEncoder()
train.YEAR = le.fit_transform(train.YEAR)
real_test.YEAR = le.fit_transform(real_test.YEAR)

# %%
def get_values(value):
    return value.values.reshape(-1, 1)

for col in train_X.columns:
    if col not in ['YEAR']:
        scaler = RobustScaler()
        train_X[col] = scaler.fit_transform(get_values(train_X[col]))
        real_test[col] = scaler.transform(get_values(real_test[col]))

# %%
train_X
# Out:
#        ANONYMOUS_1  YEAR     FE  ANONYMOUS_2        ZN       V40    PQINDEX  \
# 0        -0.345938     4  6.776     0.000000 -0.411275  0.652905  50.147929
# 1        -0.409430    14 -0.312     0.833333  0.121996 -1.029052  -0.059172
# 2         0.087768     8 -0.296     0.000000 -0.099815 -0.591743  -0.071006
# 3         2.409897     3 -0.032     0.000000 -0.474122  0.336391   0.088757
# 4         0.806256     8  0.240     0.000000 -0.362292  0.333333   1.112426
# ...            ...   ...    ...          ...       ...       ...        ...
# 14090    -0.285247     7 -0.144     0.000000 -0.465804  0.368502   0.035503
# 14091     0.260037     6 -0.232     0.000000  0.820702  0.094801  -0.118343
# 14092    -0.204949     1  2.992     1.666667  0.721811 -0.876147   3.644970
# 14093     0.126517     2 -0.176     1.666667  0.121996 -1.024465  -0.106509
# 14094    -0.151727     5 -0.248     0.000000  0.085028 -0.983180   0.307692
#
#         NI       CU         MO        CR
# 0      6.0   4.6250   0.000000  4.000000
# 1      0.0   1.6875  -0.142857 -0.333333
# 2      0.0  -0.1250  -0.142857  0.000000
# 3      0.0  -0.1875  -0.142857 -0.333333
# 4      0.0  -0.2500  -0.142857 -0.333333
# ...    ...      ...        ...       ...
# 14090  0.0  -0.0625  -0.142857 -0.333333
# 14091  0.0  -0.1250  31.857143 -0.333333
# 14092  1.0   0.1875   1.285714  1.000000
# 14093  0.0  10.3750   0.000000 -0.333333
# 14094  0.0   6.6250  -0.142857 -0.333333
#
# [14095 rows x 11 columns]

# %%
clf_cat = CatBoostRegressor(nan_mode='Min', eval_metric='RMSE', iterations=102, sampling_frequency='PerTree',
                            leaf_estimation_method='Newton', grow_policy='SymmetricTree', penalties_coefficient=1,
                            boosting_type='Plain', model_shrink_mode='Constant', feature_border_type='GreedyLogSum', 
                            eval_fraction=0, l2_leaf_reg=4, random_strength=0.7446107864379883, rsm=1, boost_from_average=True, 
                            model_size_reg=0.5, subsample=0.800000011920929, use_best_model=False, random_seed=42, 
                            depth=8, posterior_sampling=False, border_count=254, sparse_features_conflict_fraction=0, 
                            leaf_estimation_backtracking='AnyImprovement', best_model_min_trees=1, model_shrink_rate=0, 
                            min_data_in_leaf=1, loss_function='RMSE', learning_rate=0.1271568387746811, score_function='Cosine', 
                            task_type='CPU', leaf_estimation_iterations=1, bootstrap_type='MVS', max_leaves=256)

clf_gbr = GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',init=None, learning_rate=0.1, 
                                    loss='ls', max_depth=3, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, 
                                    min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=100,
                                    n_iter_no_change=None, random_state=42, subsample=1.0, tol=0.0001, validation_fraction=0.1,
                                    verbose=0, warm_start=False)

clf_lgb = lgb.LGBMRegressor(bagging_fraction=0.7148538589793427, bagging_freq=3,boosting_type='gbdt', class_weight=None, 
                            colsample_bytree=1.0, device='gpu', feature_fraction=0.5825453457757226, importance_type='split',
                            learning_rate=0.3368892510399297, max_depth=-1, min_child_samples=30, min_child_weight=0.001,
                            min_split_gain=0.21233911067827616, n_estimators=252, n_jobs=-1, num_leaves=7, objective=None, 
                            random_state=42, reg_alpha=1.0001718780584612e-08, reg_lambda=1.040997312682199e-08, silent='warn',
                            subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
clf_cat.fit(train_X, train_y)
clf_gbr.fit(train_X, train_y)
clf_lgb.fit(train_X, train_y)
# Out:
# 0:	learn: 0.2183755	total: 148ms	remaining: 14.9s
# 1:	learn: 0.2169114	total: 153ms	remaining: 7.66s
# 2:	learn: 0.2156178	total: 159ms	remaining: 5.24s
# 3:	learn: 0.2146855	total: 164ms	remaining: 4.03s
# 4:	learn: 0.2137734	total: 170ms	remaining: 3.29s
# 5:	learn: 0.2130940	total: 175ms	remaining: 2.8s
# 6:	learn: 0.2123636	total: 180ms	remaining: 2.45s
# 7:	learn: 0.2116038	total: 186ms	remaining: 2.18s
# 8:	learn: 0.2109342	total: 190ms	remaining: 1.96s
# 9:	learn: 0.2104393	total: 195ms	remaining: 1.79s
# 10:	learn: 0.2099574	total: 199ms	remaining: 1.65s
# 11:	learn: 0.2094465	total: 205ms	remaining: 1.54s
# 12:	learn: 0.2089618	total: 211ms	remaining: 1.44s
# 13:	learn: 0.2085669	total: 217ms	remaining: 1.36s
# 14:	learn: 0.2083312	total: 222ms	remaining: 1.29s
# 15:	learn: 0.2079585	total: 228ms	remaining: 1.23s
# 16:	learn: 0.2076622	total: 234ms	remaining: 1.17s
# 17:	learn: 0.2073677	total: 240ms	remaining: 1.12s
# 18:	learn: 0.2070764	total: 246ms	remaining: 1.07s
# 19:	learn: 0.2067978	total: 252ms	remaining: 1.03s
# 20:	learn: 0.2066487	total: 257ms	remaining: 992ms
# 21:	learn: 0.2064044	total: 262ms	remaining: 953ms
# 22:	learn: 0.2062114	total: 267ms	remaining: 917ms
# 23:	learn: 0.2059875	total: 272ms	remaining: 884ms
# 24:	learn: 0.2058256	total: 278ms	remaining: 856ms
# 25:	learn: 0.2056248	total: 284ms	remaining: 830ms
# 26:	learn: 0.2054253	total: 290ms	remaining: 806ms
# 27:	learn: 0.2053651	total: 294ms	remaining: 777ms
# 28:	learn: 0.2051005	total: 300ms	remaining: 755ms
# 29:	learn: 0.2049249	total: 306ms	remaining: 733ms
# 30:	learn: 0.2047170	total: 312ms	remaining: 714ms
# 31:	learn: 0.2045638	total: 318ms	remaining: 695ms
# 32:	learn: 0.2043582	total: 324ms	remaining: 678ms
# 33:	learn: 0.2041747	total: 332ms	remaining: 664ms
# 34:	learn: 0.2040287	total: 338ms	remaining: 647ms
# 35:	learn: 0.2038366	total: 343ms	remaining: 630ms
# 36:	learn: 0.2035314	total: 349ms	remaining: 613ms
# 37:	learn: 0.2033446	total: 355ms	remaining: 598ms
# 38:	learn: 0.2031636	total: 361ms	remaining: 583ms
# 39:	learn: 0.2029931	total: 367ms	remaining: 569ms
# 40:	learn: 0.2028691	total: 373ms	remaining: 555ms
# 41:	learn: 0.2028017	total: 379ms	remaining: 542ms
# 93:	learn: 0.1949314	total: 686ms	remaining: 58.4ms
# 94:	learn: 0.1948030	total: 693ms	remaining: 51.1ms
# 95:	learn: 0.1946481	total: 700ms	remaining: 43.8ms
# 96:	learn: 0.1944141	total: 707ms	remaining: 36.4ms
# 97:	learn: 0.1943473	total: 713ms	remaining: 29.1ms
# 98:	learn: 0.1941279	total: 719ms	remaining: 21.8ms
# 99:	learn: 0.1940194	total: 724ms	remaining: 14.5ms
# 100:	learn: 0.1938901	total: 728ms	remaining: 7.21ms
# 101:	learn: 0.1937928	total: 734ms	remaining: 0us
# [LightGBM] [Warning] feature_fraction is set=0.5825453457757226, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5825453457757226
# [LightGBM] [Warning] bagging_fraction is set=0.7148538589793427, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7148538589793427
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# LGBMRegressor(bagging_fraction=0.7148538589793427, bagging_freq=3, device='gpu',
#               feature_fraction=0.5825453457757226,
#               learning_rate=0.3368892510399297, min_child_samples=30,
#               min_split_gain=0.21233911067827616, n_estimators=252,
#               num_leaves=7, random_state=42, reg_alpha=1.0001718780584612e-08,
#               reg_lambda=1.040997312682199e-08)

# %%
pred_cat = clf_cat.predict(real_test)
pred_gbr = clf_gbr.predict(real_test)
pred_lgb = clf_lgb.predict(real_test)

# %%
pred = pd.DataFrame({'cat': pred_cat, 'gbr': pred_gbr, 'lgb': pred_lgb})
pred
# Out:
#            cat       gbr       lgb
# 0     0.942207  0.940200  0.942598
# 1     0.922106  0.881264  0.916034
# 2     0.883490  0.858878  0.878191
# 3     0.887884  0.912664  0.885946
# 4     0.821230  0.832220  0.826438
# ...        ...       ...       ...
# 6036  0.964216  0.943723  0.962968
# 6037  0.920347  0.918789  0.914226
# 6038  0.876644  0.868024  0.866024
# 6039  0.938225  0.944663  0.941373
# 6040  0.922201  0.964362  0.949428
#
# [6041 rows x 3 columns]

# %%
pred['mean'] = pred.mean(axis=1)
pred
# Out:
#            cat       gbr       lgb      mean
# 0     0.942207  0.940200  0.942598  0.941668
# 1     0.922106  0.881264  0.916034  0.906468
# 2     0.883490  0.858878  0.878191  0.873520
# 3     0.887884  0.912664  0.885946  0.895498
# 4     0.821230  0.832220  0.826438  0.826629
# ...        ...       ...       ...       ...
# 6036  0.964216  0.943723  0.962968  0.956969
# 6037  0.920347  0.918789  0.914226  0.917787
# 6038  0.876644  0.868024  0.866024  0.870231
# 6039  0.938225  0.944663  0.941373  0.941420
# 6040  0.922201  0.964362  0.949428  0.945331
#
# [6041 rows x 4 columns]

# %%
def label(score):
    return 0 if score > 0.85 else 1

# %%
labels = [label(score) for score in pred['mean']]

# %%
pd.DataFrame(labels).value_counts()
# Out:
# 0    5423
# 1     618
# dtype: int64

# %%
submit = pd.read_csv('C:/Users/cdbre/Desktop/MyLife/DACON/data/sample_submission.csv')
submit['Y_LABEL'] = labels
submit.head()
# Out:
#           ID  Y_LABEL
# 0  TEST_0000        0
# 1  TEST_0001        0
# 2  TEST_0002        0
# 3  TEST_0003        0
# 4  TEST_0004        1

# %%
submit.to_csv('C:/Users/cdbre/Desktop/MyLife/DACON/data/submit_fuck.csv', index=False)
